# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-L/CSE465-/blob/main/RAVDESS_SER__CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Unzip Dataset (RAVDESS)

# %% [markdown]
# # Download And Extract

# %%
# !gdown --id 1UBZLKSiAJyKoIy_cvIH94ad0EhJLO1vY # Ravdess
# !gdown --id 1a3R72CZ7IYNa68dQ9UDBQGNr8CWGnHrl # Ravdess csv
import zipfile
dataset_directory = '/content/Audio_Speech_Actors_01-24.zip' # RAVDESS
zip_ref = zipfile.ZipFile(dataset_directory, 'r')
zip_ref.extractall('Unzipped_Data')

import pandas as pd
from sklearn.model_selection import train_test_split
csv =  pd.read_csv('/content/ravdess_data.csv')
for index, row in csv.iterrows():
  if (row['Emotion_ID']==0):
    csv.drop(index, axis=0, inplace = True)

csv['Emotion_ID'].replace({1:0, 2:1, 3:2, 4:3, 5:4, 6:5, 7:6}, inplace=True)
y = pd.DataFrame(csv[['Emotion_ID']])

train_csv, test_csv = train_test_split(csv, random_state = 0, stratify=y, test_size = 0.2097, shuffle = True)


y = pd.DataFrame(train_csv[['Emotion_ID']])
train_csv, val_csv = train_test_split(train_csv, random_state = 0, stratify=y, train_size = 0.886, shuffle = True)
val_csv.to_csv(r'val_csv.csv', index=False)
train_csv.to_csv(r'train_csv.csv', index=False)
test_csv.to_csv(r'test_csv.csv', index=False)
print(len(train_csv))
print(len(test_csv))
print(len(val_csv))
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UBZLKSiAJyKoIy_cvIH94ad0EhJLO1vY
# To: /content/Audio_Speech_Actors_01-24.zip
# 100% 208M/208M [00:02<00:00, 101MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1a3R72CZ7IYNa68dQ9UDBQGNr8CWGnHrl
# To: /content/ravdess_data.csv
# 100% 94.0k/94.0k [00:00<00:00, 32.0MB/s]
# 940
# 282
# 122

# %% [markdown]
# # Custom Dataset Class

# %% [markdown]
# Create custom Dataset

# %%
import os
import torch
from torch.utils.data import Dataset
import pandas as pd
import torchaudio
from torch.utils.data import DataLoader
import torch.optim.lr_scheduler as lr_scheduler
from torch.nn.functional import normalize


class CustomDataset(Dataset):
    def __init__(self, annotations_file, audio_dir, transformation, target_sample_rate, num_samples, device):
        self.annotations = pd.read_csv(annotations_file)
        self.audio_dir = audio_dir
        self.device = device
        self.transformation = transformation.to(self.device)
        self.target_sample_rate = target_sample_rate
        self.num_samples = num_samples

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, index):
        audio_sample_path = self._get_audio_sample_path(index)
        #print(audio_sample_path)
        label = self._get_audio_sample_label(index)
        #print(label)
        #signal, sr = torchaudio.load(audio_sample_path,frame_offset=int(self.num_samples*.3),num_frames = self.target_sample_rate)
        signal, sr = torchaudio.load(audio_sample_path)
        signal = signal.to(self.device)
        signal = self._resample_if_necessary(signal, sr)
        signal = self._mix_down_if_necessary(signal)
        signal = self._cut_if_necessary(signal)
        signal = self._right_pad_if_necessary(signal)
        signal = self.transformation(signal)
        # produce delta and delta-delta and add to mfcc
        delta = torchaudio.functional.compute_deltas(signal)
        delta2 = torchaudio.functional.compute_deltas(delta)
        signal = torch.cat((signal, delta, delta2), 1) # concatenating deltas
        
        #signal = signal + delta + delta2
        means = signal.mean(dim=1, keepdim=True)
        stds = signal.std(dim=1, keepdim=True)
        signal = (signal - means) / stds #NORMALIZED

        return signal, label

    def _cut_if_necessary(self, signal):
        if signal.shape[1] > self.num_samples:
            # print(signal.shape[1]) # print sample size
            signal = signal[:, :self.num_samples]
        return signal

    def _right_pad_if_necessary(self, signal):
        length_signal = signal.shape[1]
        if length_signal < self.num_samples:
            num_missing_samples = self.num_samples - length_signal
            last_dim_padding = (0, num_missing_samples)
            signal = torch.nn.functional.pad(signal, last_dim_padding)
        return signal

    def _resample_if_necessary(self, signal, sr):
        if sr != self.target_sample_rate:
            resampler = torchaudio.transforms.Resample(sr, self.target_sample_rate)
            resampler = resampler.to(device)
            signal = resampler(signal)
        return signal

    def _mix_down_if_necessary(self, signal):
        if signal.shape[0] > 1:
            signal = torch.mean(signal, dim=0, keepdim=True)
        return signal

    # for any audio index this function returns the audio path
    def _get_audio_sample_path(self, index):
        path = os.path.join(self.audio_dir, self.annotations.iloc[index,0])
        return path
    
    # for specified audio index this will return the label from the data csv
    def _get_audio_sample_label(self, index):
        return self.annotations.iloc[index, 2]

# %% [markdown]
# Instantiate the dataset

# %%
TRAIN_CSV = '/content/train_csv.csv'
TEST_CSV = '/content/test_csv.csv'
VALID_CSV = '/content/val_csv.csv'

TRAIN_PATH = ''
TEST_PATH = ''
VALID_PATH = ''

SAMPLE_RATE = 48000
NUM_SAMPLES = SAMPLE_RATE*4

device = ''
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"
print(f"Using device {device}")

#mfcc = torchaudio.transforms.MelSpectrogram(sample_rate=SAMPLE_RATE, n_mels = 70,n_fft = 600)
mfcc = torchaudio.transforms.MFCC(sample_rate=SAMPLE_RATE, n_mfcc=44, melkwargs={"n_fft": 1536, "hop_length": 512, "power": 2})
train_dataset = CustomDataset(TRAIN_CSV,
                        TRAIN_PATH,
                        mfcc,
                        SAMPLE_RATE,
                        NUM_SAMPLES,
                        device)
print(f"There are {len(train_dataset)} samples in the train.")

val_dataset = CustomDataset(VALID_CSV,
                        VALID_PATH,
                        mfcc,
                        SAMPLE_RATE,
                        NUM_SAMPLES,
                        device)

print(f"There are {len(val_dataset)} samples in the valid.")

test_dataset = CustomDataset(TEST_CSV,
                        TEST_PATH,
                        mfcc,
                        SAMPLE_RATE,
                        NUM_SAMPLES,
                        device)
print(f"There are {len(test_dataset)} samples in the test.")
signal, label = val_dataset[0]
print(signal.shape)
# Out:
# Using device cuda
# There are 940 samples in the train.
# There are 122 samples in the valid.
# There are 282 samples in the test.
# torch.Size([1, 132, 376])

# %%
import math
#Calculate outputs:
def CalculateConv2dOutput(W, F, P, S):
  return math.floor((W - F + 2 * P) / S ) + 1

def MaxPool2d(W, F, P, S):
  return math.floor((W - F) / S ) + 1


#layer 1
a = CalculateConv2dOutput(132, 3, 2, 1)
b = CalculateConv2dOutput(376, 3, 2, 1)

a = MaxPool2d(a, 2, 0, 2)
b = MaxPool2d(b, 2, 0, 2)
#layer 2
a = CalculateConv2dOutput(a, 3, 2, 1)
b = CalculateConv2dOutput(b, 3, 2, 1)

a = MaxPool2d(a, 2, 0, 2)
b = MaxPool2d(b, 2, 0, 2)

#layer 3
a = CalculateConv2dOutput(a, 3, 2, 1)
b = CalculateConv2dOutput(b, 3, 2, 1)

a = MaxPool2d(a, 2, 0, 2)
b = MaxPool2d(b, 2, 0, 2)
# layer 4
a = CalculateConv2dOutput(a, 3, 2, 1)
b = CalculateConv2dOutput(b, 3, 2, 1)

a = MaxPool2d(a, 2, 0, 2)
b = MaxPool2d(b, 2, 0, 2)

print(a)
print(b)
# Out:
# 10
# 25

# %% [markdown]
# # Model Loading and Functions

# %%
from torch import nn
from torchsummary import summary

class CNNNetwork(nn.Module):

    def __init__(self):
        super().__init__()
        # 4 conv blocks / flatten / linear / softmax
        self.conv1 = nn.Sequential(            # shape = 66,132
            nn.Conv2d(
                in_channels=1,
                out_channels=16,
                kernel_size=3,
                stride=1,
                padding=2
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)      # shape after maxpool = 33, 66
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(
                in_channels=16,
                out_channels=32,
                kernel_size=3,
                stride=1,
                padding=2
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=3,
                stride=1,
                padding=2
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(
                in_channels=64,
                out_channels=128,
                kernel_size=3,
                stride=1,
                padding=2
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.flatten = nn.Flatten()
        self.linear = nn.Linear(128 *10*25, 512)
        self.linear2 = nn.Linear(512, 256)
        self.linear3 = nn.Linear(256, 128)
        self.linear4 = nn.Linear(128, 7) # 7 outputs # added linear layers
        self.softmax = nn.Softmax(dim=1)

    def forward(self, input_data):
        x = self.conv1(input_data)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.flatten(x)
        x = self.linear(x)
        x = self.linear2(x)
        x = self.linear3(x)
        logits = self.linear4(x)
        predictions = self.softmax(logits)
        return predictions


if __name__ == "__main__":
    model = CNNNetwork().to(device)

summary(model, (signal.shape))

# %%
#!gdown --id 18hQTkVXPjlmxhFmpD2U9Qa_uhvYUY3M_
#model = torch.load('/content/Resnet_high_model.pth')
model = model.to(device)
#summary(model, signal.shape)

# %% [markdown]
# # Model Parameter Setting

# %%
from torch import nn
train_loss = []
val_loss = []
test_loss = []

train_acc = []
val_acc = []
test_acc = []

BATCH_SIZE = 32
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=10**-4)

#optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
#step_lr_scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='max',factor=0.1,patience=2, verbos=True)
#step_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

def create_data_loader(train_data, batch_size):
    train_dataloader = DataLoader(train_data, batch_size=batch_size)
    return train_dataloader

train_dataloader = create_data_loader(train_dataset, BATCH_SIZE)
test_dataloader = create_data_loader(test_dataset, BATCH_SIZE)
val_dataloader = create_data_loader(val_dataset, BATCH_SIZE)

# %%
def train_loop(dataloader, model, criterion, optimizer):
    model.train()
    running_loss = 0.0
    running_corrects = 0
    size = len(dataloader.dataset)  

    for batch, (X,y) in enumerate(dataloader):
        # Compute prediction and loss
        inputs, labels = X.to(device), y.to(device)
        
        with torch.set_grad_enabled(True):
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        if batch % 80 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

    epoch_loss = running_loss / size
    epoch_acc = running_corrects.double() / size

    print('Train      Loss: {:.4f} Acc: {:.4f}'.format(
                 epoch_loss, epoch_acc))
    
    return epoch_loss, epoch_acc

# %%
def test_loop(dataloader, model, criterion):
    #model.eval()
    running_loss = 0.0
    running_corrects = 0
    size = len(dataloader.dataset)  

    for batch, (X,y) in enumerate(dataloader):
        # Compute prediction and loss
        inputs, labels = X.to(device), y.to(device)
        
        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / size
    epoch_acc = running_corrects.double() / size

    print('Validation Loss: {:.4f} Acc: {:.4f}'.format(
                 epoch_loss, epoch_acc))
    
    return epoch_loss,epoch_acc

# %% [markdown]
# # Model Running

# %%
import math
import time
import copy

best_model_wts = copy.deepcopy(model.state_dict())
best_acc = 0.0

EPOCHS = 250
start = time.time()
for t in range(EPOCHS):
    print(f"\nEpoch {t+1}\n-------------------------------")
    ls , ac = train_loop(train_dataloader, model, criterion, optimizer)
    train_loss.append(ls)
    train_acc.append(ac)

    ls,ac = test_loop(val_dataloader, model, criterion)
    val_loss.append(ls)
    val_acc.append(ac)

    # #testing 
    # ls,ac = test_loop(test_dataloader, model, criterion)
    # test_loss.append(ls)
    # test_acc.append(ac)
    # #testing 

    if ac > best_acc:
        best_acc = ac
        best_model_wts = copy.deepcopy(model.state_dict())

    #step_lr_scheduler.step()
    
final = (time.time() - start)/60
model.load_state_dict(best_model_wts)
print(f"Done for all {EPOCHS} epochs in {math.ceil(final)} minutes\n")
print(f"Best Validation accuracy: {best_acc} \n")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.943347  [    0/  940]
# Train      Loss: 1.9400 Acc: 0.1489
# Validation Loss: 1.9091 Acc: 0.2787
#
# Epoch 2
# -------------------------------
# loss: 1.916679  [    0/  940]
# Train      Loss: 1.8769 Acc: 0.2766
# Validation Loss: 1.8000 Acc: 0.3607
#
# Epoch 3
# -------------------------------
# loss: 1.796848  [    0/  940]
# Train      Loss: 1.8025 Acc: 0.3745
# Validation Loss: 1.7772 Acc: 0.3525
#
# Epoch 4
# -------------------------------
# loss: 1.772030  [    0/  940]
# Train      Loss: 1.7716 Acc: 0.3894
# Validation Loss: 1.7662 Acc: 0.3770
#
# Epoch 5
# -------------------------------
# loss: 1.709139  [    0/  940]
# Train      Loss: 1.7649 Acc: 0.3957
# Validation Loss: 1.7522 Acc: 0.3770
#
# Epoch 6
# -------------------------------
# loss: 1.766048  [    0/  940]
# Train      Loss: 1.7548 Acc: 0.4128
# Validation Loss: 1.7490 Acc: 0.4016
#
# Epoch 7
# -------------------------------
# loss: 1.711175  [    0/  940]
# Train      Loss: 1.7497 Acc: 0.4074
# Validation Loss: 1.7344 Acc: 0.4262
#
# Epoch 8
# -------------------------------
# loss: 1.704895  [    0/  940]
# Train      Loss: 1.7477 Acc: 0.4128
# Validation Loss: 1.7465 Acc: 0.4016
#
# Epoch 9
# -------------------------------
# loss: 1.707740  [    0/  940]
# Train      Loss: 1.7635 Acc: 0.3968
# Validation Loss: 1.7730 Acc: 0.3689
#
# Epoch 10
# -------------------------------
# loss: 1.758611  [    0/  940]
# Train      Loss: 1.7633 Acc: 0.3904
# Validation Loss: 1.7310 Acc: 0.4344
#
# Epoch 11
# -------------------------------
# loss: 1.668258  [    0/  940]
# Train      Loss: 1.7698 Acc: 0.3883
# Validation Loss: 1.7466 Acc: 0.4262
#
# Epoch 12
# -------------------------------
# loss: 1.730874  [    0/  940]
# Train      Loss: 1.7453 Acc: 0.4117
# Validation Loss: 1.7205 Acc: 0.4426
#
# Epoch 13
# -------------------------------
# loss: 1.700929  [    0/  940]
# Train      Loss: 1.7361 Acc: 0.4181
# Validation Loss: 1.6989 Acc: 0.4672
#
# Epoch 14
# -------------------------------
# loss: 1.693604  [    0/  940]
# Train      Loss: 1.7324 Acc: 0.4266
# Validation Loss: 1.7025 Acc: 0.4426
#
# Epoch 15
# -------------------------------
# loss: 1.671974  [    0/  940]
# Train      Loss: 1.7235 Acc: 0.4362
# Validation Loss: 1.7047 Acc: 0.4508
#
# Epoch 16
# -------------------------------
# loss: 1.667828  [    0/  940]
# Train      Loss: 1.7186 Acc: 0.4457
# Validation Loss: 1.7144 Acc: 0.4508
#
# Epoch 17
# -------------------------------
# loss: 1.668969  [    0/  940]
# Train      Loss: 1.7215 Acc: 0.4362
# Validation Loss: 1.7261 Acc: 0.4426
#
# Epoch 18
# -------------------------------
# loss: 1.642193  [    0/  940]
# Train      Loss: 1.7233 Acc: 0.4394
# Validation Loss: 1.7069 Acc: 0.4426
#
# Epoch 19
# -------------------------------
# loss: 1.641478  [    0/  940]
# Train      Loss: 1.7239 Acc: 0.4383
# Validation Loss: 1.6998 Acc: 0.4590
#
# Epoch 20
# -------------------------------
# loss: 1.643033  [    0/  940]
# Train      Loss: 1.6924 Acc: 0.4702
# Validation Loss: 1.7036 Acc: 0.4426
#
# Epoch 21
# -------------------------------
# loss: 1.635401  [    0/  940]
# Train      Loss: 1.6970 Acc: 0.4585
# Validation Loss: 1.7022 Acc: 0.4344
#
# Epoch 22
# -------------------------------
# loss: 1.628596  [    0/  940]
# Train      Loss: 1.6820 Acc: 0.4926
# Validation Loss: 1.6954 Acc: 0.4426
#
# Epoch 23
# -------------------------------
# loss: 1.614783  [    0/  940]
# Train      Loss: 1.6746 Acc: 0.4947
# Validation Loss: 1.6878 Acc: 0.4426
#
# Epoch 24
# -------------------------------
# loss: 1.608013  [    0/  940]
# Train      Loss: 1.6619 Acc: 0.5128
# Validation Loss: 1.6797 Acc: 0.4590
#
# Epoch 25
# -------------------------------
# loss: 1.607067  [    0/  940]
# Train      Loss: 1.6550 Acc: 0.5266
# Validation Loss: 1.6621 Acc: 0.4836
#
# Epoch 26
# -------------------------------
# loss: 1.580992  [    0/  940]
# Train      Loss: 1.6455 Acc: 0.5372
# Validation Loss: 1.6543 Acc: 0.5000
#
# Epoch 27
# -------------------------------
# loss: 1.602864  [    0/  940]
# Train      Loss: 1.6433 Acc: 0.5351
# Validation Loss: 1.6556 Acc: 0.5000
#
# Epoch 28
# -------------------------------
# loss: 1.620317  [    0/  940]
# Train      Loss: 1.6514 Acc: 0.5149
# Validation Loss: 1.6508 Acc: 0.5082
#
# Epoch 29
# -------------------------------
# loss: 1.593487  [    0/  940]
# Train      Loss: 1.6438 Acc: 0.5319
# Validation Loss: 1.6564 Acc: 0.5000
#
# Epoch 30
# -------------------------------
# loss: 1.566319  [    0/  940]
# Train      Loss: 1.6486 Acc: 0.5160
# Validation Loss: 1.6556 Acc: 0.5000
#
# Epoch 31
# -------------------------------
# loss: 1.565785  [    0/  940]
# Train      Loss: 1.6382 Acc: 0.5277
# Validation Loss: 1.6585 Acc: 0.5000
#
# Epoch 32
# -------------------------------
# loss: 1.548206  [    0/  940]
# Train      Loss: 1.6309 Acc: 0.5394
# Validation Loss: 1.6543 Acc: 0.5164
#
# Epoch 33
# -------------------------------
# loss: 1.557147  [    0/  940]
# Train      Loss: 1.6494 Acc: 0.5117
# Validation Loss: 1.6415 Acc: 0.5246
#
# Epoch 34
# -------------------------------
# loss: 1.547587  [    0/  940]
# Train      Loss: 1.6221 Acc: 0.5457
# Validation Loss: 1.6434 Acc: 0.5164
#
# Epoch 35
# -------------------------------
# loss: 1.539733  [    0/  940]
# Train      Loss: 1.6136 Acc: 0.5596
# Validation Loss: 1.6413 Acc: 0.5246
#
# Epoch 36
# -------------------------------
# loss: 1.515444  [    0/  940]
# Train      Loss: 1.6074 Acc: 0.5606
# Validation Loss: 1.6241 Acc: 0.5492
#
# Epoch 37
# -------------------------------
# loss: 1.505711  [    0/  940]
# Train      Loss: 1.5947 Acc: 0.5777
# Validation Loss: 1.6231 Acc: 0.5246
#
# Epoch 38
# -------------------------------
# loss: 1.502323  [    0/  940]
# Train      Loss: 1.5823 Acc: 0.5872
# Validation Loss: 1.6160 Acc: 0.5574
#
# Epoch 39
# -------------------------------
# loss: 1.533322  [    0/  940]
# Train      Loss: 1.5761 Acc: 0.5979
# Validation Loss: 1.6180 Acc: 0.5492
#
# Epoch 40
# -------------------------------
# loss: 1.567020  [    0/  940]
# Train      Loss: 1.5738 Acc: 0.5936
# Validation Loss: 1.6214 Acc: 0.5656
#
# Epoch 41
# -------------------------------
# loss: 1.519583  [    0/  940]
# Train      Loss: 1.5558 Acc: 0.6170
# Validation Loss: 1.6185 Acc: 0.5492
#
# Epoch 42
# -------------------------------
# loss: 1.477954  [    0/  940]
# Train      Loss: 1.5437 Acc: 0.6383
# Validation Loss: 1.6150 Acc: 0.5328
#
# Epoch 43
# -------------------------------
# loss: 1.483379  [    0/  940]
# Train      Loss: 1.5322 Acc: 0.6489
# Validation Loss: 1.6124 Acc: 0.5492
#
# Epoch 44
# -------------------------------
# loss: 1.480629  [    0/  940]
# Train      Loss: 1.5227 Acc: 0.6500
# Validation Loss: 1.6162 Acc: 0.5246
#
# Epoch 45
# -------------------------------
# loss: 1.475777  [    0/  940]
# Train      Loss: 1.5114 Acc: 0.6660
# Validation Loss: 1.6071 Acc: 0.5574
#
# Epoch 46
# -------------------------------
# loss: 1.460660  [    0/  940]
# Train      Loss: 1.5082 Acc: 0.6723
# Validation Loss: 1.6345 Acc: 0.5082
#
# Epoch 47
# -------------------------------
# loss: 1.481775  [    0/  940]
# Train      Loss: 1.5006 Acc: 0.6766
# Validation Loss: 1.6187 Acc: 0.5410
#
# Epoch 48
# -------------------------------
# loss: 1.474445  [    0/  940]
# Train      Loss: 1.5028 Acc: 0.6766
# Validation Loss: 1.6376 Acc: 0.5164
#
# Epoch 49
# -------------------------------
# loss: 1.506135  [    0/  940]
# Train      Loss: 1.5445 Acc: 0.6234
# Validation Loss: 1.6008 Acc: 0.5820
#
# Epoch 50
# -------------------------------
# loss: 1.422681  [    0/  940]
# Train      Loss: 1.5096 Acc: 0.6638
# Validation Loss: 1.5872 Acc: 0.5902
#
# Epoch 51
# -------------------------------
# loss: 1.449523  [    0/  940]
# Train      Loss: 1.5185 Acc: 0.6447
# Validation Loss: 1.6659 Acc: 0.4836
#
# Epoch 52
# -------------------------------
# loss: 1.523329  [    0/  940]
# Train      Loss: 1.5178 Acc: 0.6553
# Validation Loss: 1.6168 Acc: 0.5410
#
# Epoch 53
# -------------------------------
# loss: 1.452320  [    0/  940]
# Train      Loss: 1.4988 Acc: 0.6660
# Validation Loss: 1.6012 Acc: 0.5492
#
# Epoch 54
# -------------------------------
# loss: 1.410546  [    0/  940]
# Train      Loss: 1.4680 Acc: 0.7011
# Validation Loss: 1.5810 Acc: 0.5820
#
# Epoch 55
# -------------------------------
# loss: 1.379661  [    0/  940]
# Train      Loss: 1.4614 Acc: 0.7096
# Validation Loss: 1.5957 Acc: 0.5656
#
# Epoch 56
# -------------------------------
# loss: 1.386322  [    0/  940]
# Train      Loss: 1.4508 Acc: 0.7213
# Validation Loss: 1.5996 Acc: 0.5574
#
# Epoch 57
# -------------------------------
# loss: 1.373847  [    0/  940]
# Train      Loss: 1.4502 Acc: 0.7223
# Validation Loss: 1.5811 Acc: 0.5820
#
# Epoch 58
# -------------------------------
# loss: 1.364695  [    0/  940]
# Train      Loss: 1.4463 Acc: 0.7266
# Validation Loss: 1.5917 Acc: 0.5738
#
# Epoch 59
# -------------------------------
# loss: 1.357675  [    0/  940]
# Train      Loss: 1.4415 Acc: 0.7309
# Validation Loss: 1.6045 Acc: 0.5492
#
# Epoch 60
# -------------------------------
# loss: 1.370906  [    0/  940]
# Train      Loss: 1.4381 Acc: 0.7351
# Validation Loss: 1.5929 Acc: 0.5656
#
# Epoch 61
# -------------------------------
# loss: 1.368804  [    0/  940]
# Train      Loss: 1.4408 Acc: 0.7287
# Validation Loss: 1.6144 Acc: 0.5410
#
# Epoch 62
# -------------------------------
# loss: 1.363638  [    0/  940]
# Train      Loss: 1.4367 Acc: 0.7351
# Validation Loss: 1.5887 Acc: 0.5820
#
# Epoch 63
# -------------------------------
# loss: 1.348404  [    0/  940]
# Train      Loss: 1.4315 Acc: 0.7404
# Validation Loss: 1.5864 Acc: 0.5656
#
# Epoch 64
# -------------------------------
# loss: 1.343991  [    0/  940]
# Train      Loss: 1.4328 Acc: 0.7383
# Validation Loss: 1.5840 Acc: 0.5820
#
# Epoch 65
# -------------------------------
# loss: 1.341116  [    0/  940]
# Train      Loss: 1.4258 Acc: 0.7415
# Validation Loss: 1.5971 Acc: 0.5656
#
# Epoch 66
# -------------------------------
# loss: 1.351808  [    0/  940]
# Train      Loss: 1.4181 Acc: 0.7500
# Validation Loss: 1.6078 Acc: 0.5492
#
# Epoch 67
# -------------------------------
# loss: 1.329728  [    0/  940]
# Train      Loss: 1.4201 Acc: 0.7479
# Validation Loss: 1.6036 Acc: 0.5492
#
# Epoch 68
# -------------------------------
# loss: 1.346548  [    0/  940]
# Train      Loss: 1.4164 Acc: 0.7532
# Validation Loss: 1.5871 Acc: 0.5738
#
# Epoch 69
# -------------------------------
# loss: 1.338150  [    0/  940]
# Train      Loss: 1.4126 Acc: 0.7553
# Validation Loss: 1.5921 Acc: 0.5738
#
# Epoch 70
# -------------------------------
# loss: 1.322451  [    0/  940]
# Train      Loss: 1.4103 Acc: 0.7564
# Validation Loss: 1.6006 Acc: 0.5574
#
# Epoch 71
# -------------------------------
# loss: 1.326846  [    0/  940]
# Train      Loss: 1.4105 Acc: 0.7553
# Validation Loss: 1.6008 Acc: 0.5492
#
# Epoch 72
# -------------------------------
# loss: 1.337275  [    0/  940]
# Train      Loss: 1.4095 Acc: 0.7585
# Validation Loss: 1.5927 Acc: 0.5574
#
# Epoch 73
# -------------------------------
# loss: 1.320433  [    0/  940]
# Train      Loss: 1.4068 Acc: 0.7585
# Validation Loss: 1.6023 Acc: 0.5492
#
# Epoch 74
# -------------------------------
# loss: 1.324816  [    0/  940]
# Train      Loss: 1.4072 Acc: 0.7585
# Validation Loss: 1.6015 Acc: 0.5492
#
# Epoch 75
# -------------------------------
# loss: 1.349752  [    0/  940]
# Train      Loss: 1.4140 Acc: 0.7553
# Validation Loss: 1.6009 Acc: 0.5410
#
# Epoch 76
# -------------------------------
# loss: 1.332114  [    0/  940]
# Train      Loss: 1.4097 Acc: 0.7574
# Validation Loss: 1.5910 Acc: 0.5820
#
# Epoch 77
# -------------------------------
# loss: 1.327198  [    0/  940]
# Train      Loss: 1.4071 Acc: 0.7596
# Validation Loss: 1.5992 Acc: 0.5656
#
# Epoch 78
# -------------------------------
# loss: 1.342725  [    0/  940]
# Train      Loss: 1.4084 Acc: 0.7596
# Validation Loss: 1.5903 Acc: 0.5738
#
# Epoch 79
# -------------------------------
# loss: 1.342550  [    0/  940]
# Train      Loss: 1.4227 Acc: 0.7468
# Validation Loss: 1.5858 Acc: 0.5902
#
# Epoch 80
# -------------------------------
# loss: 1.336251  [    0/  940]
# Train      Loss: 1.4085 Acc: 0.7574
# Validation Loss: 1.5704 Acc: 0.5902
#
# Epoch 81
# -------------------------------
# loss: 1.322340  [    0/  940]
# Train      Loss: 1.4045 Acc: 0.7596
# Validation Loss: 1.6129 Acc: 0.5410
#
# Epoch 82
# -------------------------------
# loss: 1.353589  [    0/  940]
# Train      Loss: 1.4049 Acc: 0.7649
# Validation Loss: 1.6052 Acc: 0.5492
#
# Epoch 83
# -------------------------------
# loss: 1.326080  [    0/  940]
# Train      Loss: 1.3989 Acc: 0.7660
# Validation Loss: 1.5775 Acc: 0.5738
#
# Epoch 84
# -------------------------------
# loss: 1.321412  [    0/  940]
# Train      Loss: 1.3996 Acc: 0.7670
# Validation Loss: 1.6030 Acc: 0.5574
#
# Epoch 85
# -------------------------------
# loss: 1.325502  [    0/  940]
# Train      Loss: 1.3972 Acc: 0.7702
# Validation Loss: 1.5869 Acc: 0.5738
#
# Epoch 86
# -------------------------------
# loss: 1.317956  [    0/  940]
# Train      Loss: 1.3818 Acc: 0.7872
# Validation Loss: 1.5695 Acc: 0.6148
#
# Epoch 87
# -------------------------------
# loss: 1.294363  [    0/  940]
# Train      Loss: 1.3690 Acc: 0.8021
# Validation Loss: 1.5938 Acc: 0.5410
#
# Epoch 88
# -------------------------------
# loss: 1.313946  [    0/  940]
# Train      Loss: 1.3566 Acc: 0.8170
# Validation Loss: 1.6063 Acc: 0.5328
#
# Epoch 89
# -------------------------------
# loss: 1.329086  [    0/  940]
# Train      Loss: 1.3499 Acc: 0.8202
# Validation Loss: 1.5585 Acc: 0.6066
#
# Epoch 90
# -------------------------------
# loss: 1.294655  [    0/  940]
# Train      Loss: 1.3514 Acc: 0.8202
# Validation Loss: 1.5915 Acc: 0.5820
#
# Epoch 91
# -------------------------------
# loss: 1.305931  [    0/  940]
# Train      Loss: 1.3377 Acc: 0.8362
# Validation Loss: 1.6068 Acc: 0.5410
#
# Epoch 92
# -------------------------------
# loss: 1.308219  [    0/  940]
# Train      Loss: 1.3464 Acc: 0.8266
# Validation Loss: 1.5770 Acc: 0.5902
#
# Epoch 93
# -------------------------------
# loss: 1.294205  [    0/  940]
# Train      Loss: 1.3401 Acc: 0.8287
# Validation Loss: 1.5698 Acc: 0.5984
#
# Epoch 94
# -------------------------------
# loss: 1.296049  [    0/  940]
# Train      Loss: 1.3367 Acc: 0.8351
# Validation Loss: 1.5688 Acc: 0.5902
#
# Epoch 95
# -------------------------------
# loss: 1.313941  [    0/  940]
# Train      Loss: 1.3325 Acc: 0.8394
# Validation Loss: 1.5467 Acc: 0.5984
#
# Epoch 96
# -------------------------------
# loss: 1.291014  [    0/  940]
# Train      Loss: 1.3149 Acc: 0.8553
# Validation Loss: 1.5637 Acc: 0.5984
#
# Epoch 97
# -------------------------------
# loss: 1.306750  [    0/  940]
# Train      Loss: 1.3089 Acc: 0.8617
# Validation Loss: 1.5759 Acc: 0.5820
#
# Epoch 98
# -------------------------------
# loss: 1.287285  [    0/  940]
# Train      Loss: 1.3063 Acc: 0.8606
# Validation Loss: 1.5455 Acc: 0.6230
#
# Epoch 99
# -------------------------------
# loss: 1.273020  [    0/  940]
# Train      Loss: 1.3042 Acc: 0.8670
# Validation Loss: 1.5856 Acc: 0.5820
#
# Epoch 100
# -------------------------------
# loss: 1.299766  [    0/  940]
# Train      Loss: 1.3084 Acc: 0.8628
# Validation Loss: 1.5409 Acc: 0.6311
#
# Epoch 101
# -------------------------------
# loss: 1.259640  [    0/  940]
# Train      Loss: 1.2927 Acc: 0.8766
# Validation Loss: 1.5287 Acc: 0.6475
#
# Epoch 102
# -------------------------------
# loss: 1.276796  [    0/  940]
# Train      Loss: 1.2886 Acc: 0.8777
# Validation Loss: 1.5268 Acc: 0.6475
#
# Epoch 103
# -------------------------------
# loss: 1.260203  [    0/  940]
# Train      Loss: 1.2795 Acc: 0.8883
# Validation Loss: 1.5212 Acc: 0.6639
#
# Epoch 104
# -------------------------------
# loss: 1.276675  [    0/  940]
# Train      Loss: 1.2753 Acc: 0.8926
# Validation Loss: 1.5193 Acc: 0.6393
#
# Epoch 105
# -------------------------------
# loss: 1.258034  [    0/  940]
# Train      Loss: 1.2731 Acc: 0.8926
# Validation Loss: 1.5347 Acc: 0.6311
#
# Epoch 106
# -------------------------------
# loss: 1.257984  [    0/  940]
# Train      Loss: 1.2735 Acc: 0.8926
# Validation Loss: 1.5212 Acc: 0.6393
#
# Epoch 107
# -------------------------------
# loss: 1.256548  [    0/  940]
# Train      Loss: 1.2714 Acc: 0.8968
# Validation Loss: 1.5420 Acc: 0.6148
#
# Epoch 108
# -------------------------------
# loss: 1.274633  [    0/  940]
# Train      Loss: 1.2714 Acc: 0.8957
# Validation Loss: 1.5321 Acc: 0.6230
#
# Epoch 109
# -------------------------------
# loss: 1.262287  [    0/  940]
# Train      Loss: 1.2696 Acc: 0.8957
# Validation Loss: 1.5023 Acc: 0.6639
#
# Epoch 110
# -------------------------------
# loss: 1.259720  [    0/  940]
# Train      Loss: 1.2666 Acc: 0.8989
# Validation Loss: 1.5049 Acc: 0.6557
#
# Epoch 111
# -------------------------------
# loss: 1.258581  [    0/  940]
# Train      Loss: 1.2655 Acc: 0.8989
# Validation Loss: 1.5148 Acc: 0.6557
#
# Epoch 112
# -------------------------------
# loss: 1.257047  [    0/  940]
# Train      Loss: 1.2644 Acc: 0.9011
# Validation Loss: 1.5168 Acc: 0.6393
#
# Epoch 113
# -------------------------------
# loss: 1.256952  [    0/  940]
# Train      Loss: 1.2635 Acc: 0.9011
# Validation Loss: 1.5081 Acc: 0.6639
#
# Epoch 114
# -------------------------------
# loss: 1.257495  [    0/  940]
# Train      Loss: 1.2630 Acc: 0.9021
# Validation Loss: 1.5032 Acc: 0.6721
#
# Epoch 115
# -------------------------------
# loss: 1.257358  [    0/  940]
# Train      Loss: 1.2631 Acc: 0.9021
# Validation Loss: 1.5073 Acc: 0.6557
#
# Epoch 116
# -------------------------------
# loss: 1.258368  [    0/  940]
# Train      Loss: 1.2612 Acc: 0.9043
# Validation Loss: 1.5042 Acc: 0.6639
#
# Epoch 117
# -------------------------------
# loss: 1.257624  [    0/  940]
# Train      Loss: 1.2606 Acc: 0.9043
# Validation Loss: 1.5057 Acc: 0.6475
#
# Epoch 118
# -------------------------------
# loss: 1.256898  [    0/  940]
# Train      Loss: 1.2601 Acc: 0.9043
# Validation Loss: 1.5017 Acc: 0.6639
#
# Epoch 119
# -------------------------------
# loss: 1.256756  [    0/  940]
# Train      Loss: 1.2598 Acc: 0.9053
# Validation Loss: 1.5059 Acc: 0.6557
#
# Epoch 120
# -------------------------------
# loss: 1.256422  [    0/  940]
# Train      Loss: 1.2591 Acc: 0.9053
# Validation Loss: 1.5034 Acc: 0.6557
#
# Epoch 121
# -------------------------------
# loss: 1.257171  [    0/  940]
# Train      Loss: 1.2586 Acc: 0.9053
# Validation Loss: 1.5010 Acc: 0.6721
#
# Epoch 122
# -------------------------------
# loss: 1.261050  [    0/  940]
# Train      Loss: 1.2582 Acc: 0.9074
# Validation Loss: 1.5077 Acc: 0.6557
#
# Epoch 123
# -------------------------------
# loss: 1.259116  [    0/  940]
# Train      Loss: 1.2574 Acc: 0.9074
# Validation Loss: 1.4982 Acc: 0.6803
#
# Epoch 124
# -------------------------------
# loss: 1.258218  [    0/  940]
# Train      Loss: 1.2579 Acc: 0.9074
# Validation Loss: 1.5017 Acc: 0.6639
#
# Epoch 125
# -------------------------------
# loss: 1.257825  [    0/  940]
# Train      Loss: 1.2570 Acc: 0.9085
# Validation Loss: 1.4907 Acc: 0.6803
#
# Epoch 126
# -------------------------------
# loss: 1.256304  [    0/  940]
# Train      Loss: 1.2578 Acc: 0.9074
# Validation Loss: 1.4988 Acc: 0.6639
#
# Epoch 127
# -------------------------------
# loss: 1.256930  [    0/  940]
# Train      Loss: 1.2602 Acc: 0.9074
# Validation Loss: 1.5225 Acc: 0.6393
#
# Epoch 128
# -------------------------------
# loss: 1.257983  [    0/  940]
# Train      Loss: 1.2731 Acc: 0.8989
# Validation Loss: 1.5345 Acc: 0.6393
#
# Epoch 129
# -------------------------------
# loss: 1.269634  [    0/  940]
# Train      Loss: 1.2641 Acc: 0.9053
# Validation Loss: 1.5156 Acc: 0.6557
#
# Epoch 130
# -------------------------------
# loss: 1.270524  [    0/  940]
# Train      Loss: 1.2593 Acc: 0.9074
# Validation Loss: 1.4916 Acc: 0.6803
#
# Epoch 131
# -------------------------------
# loss: 1.258170  [    0/  940]
# Train      Loss: 1.2580 Acc: 0.9085
# Validation Loss: 1.5022 Acc: 0.6557
#
# Epoch 132
# -------------------------------
# loss: 1.260165  [    0/  940]
# Train      Loss: 1.2559 Acc: 0.9096
# Validation Loss: 1.4938 Acc: 0.6803
#
# Epoch 133
# -------------------------------
# loss: 1.256691  [    0/  940]
# Train      Loss: 1.2556 Acc: 0.9096
# Validation Loss: 1.4854 Acc: 0.6803
#
# Epoch 134
# -------------------------------
# loss: 1.257599  [    0/  940]
# Train      Loss: 1.2558 Acc: 0.9106
# Validation Loss: 1.4742 Acc: 0.6967
#
# Epoch 135
# -------------------------------
# loss: 1.257467  [    0/  940]
# Train      Loss: 1.2597 Acc: 0.9064
# Validation Loss: 1.5298 Acc: 0.6230
#
# Epoch 136
# -------------------------------
# loss: 1.274113  [    0/  940]
# Train      Loss: 1.2636 Acc: 0.9053
# Validation Loss: 1.4849 Acc: 0.6885
#
# Epoch 137
# -------------------------------
# loss: 1.259278  [    0/  940]
# Train      Loss: 1.2642 Acc: 0.9074
# Validation Loss: 1.5349 Acc: 0.6148
#
# Epoch 138
# -------------------------------
# loss: 1.264219  [    0/  940]
# Train      Loss: 1.2654 Acc: 0.9032
# Validation Loss: 1.5577 Acc: 0.5984
#
# Epoch 139
# -------------------------------
# loss: 1.267524  [    0/  940]
# Train      Loss: 1.2578 Acc: 0.9117
# Validation Loss: 1.5309 Acc: 0.6230
#
# Epoch 140
# -------------------------------
# loss: 1.259867  [    0/  940]
# Train      Loss: 1.2595 Acc: 0.9096
# Validation Loss: 1.5201 Acc: 0.6393
#
# Epoch 141
# -------------------------------
# loss: 1.262795  [    0/  940]
# Train      Loss: 1.2522 Acc: 0.9160
# Validation Loss: 1.5105 Acc: 0.6557
#
# Epoch 142
# -------------------------------
# loss: 1.262867  [    0/  940]
# Train      Loss: 1.2478 Acc: 0.9181
# Validation Loss: 1.4876 Acc: 0.6721
#
# Epoch 143
# -------------------------------
# loss: 1.256462  [    0/  940]
# Train      Loss: 1.2457 Acc: 0.9213
# Validation Loss: 1.5062 Acc: 0.6639
#
# Epoch 144
# -------------------------------
# loss: 1.257704  [    0/  940]
# Train      Loss: 1.2435 Acc: 0.9213
# Validation Loss: 1.5079 Acc: 0.6393
#
# Epoch 145
# -------------------------------
# loss: 1.257019  [    0/  940]
# Train      Loss: 1.2425 Acc: 0.9223
# Validation Loss: 1.4898 Acc: 0.6721
#
# Epoch 146
# -------------------------------
# loss: 1.257110  [    0/  940]
# Train      Loss: 1.2424 Acc: 0.9234
# Validation Loss: 1.5103 Acc: 0.6311
#
# Epoch 147
# -------------------------------
# loss: 1.257969  [    0/  940]
# Train      Loss: 1.2409 Acc: 0.9234
# Validation Loss: 1.4934 Acc: 0.6803
#
# Epoch 148
# -------------------------------
# loss: 1.257178  [    0/  940]
# Train      Loss: 1.2381 Acc: 0.9266
# Validation Loss: 1.5061 Acc: 0.6639
#
# Epoch 149
# -------------------------------
# loss: 1.258089  [    0/  940]
# Train      Loss: 1.2386 Acc: 0.9255
# Validation Loss: 1.5085 Acc: 0.6557
#
# Epoch 150
# -------------------------------
# loss: 1.259342  [    0/  940]
# Train      Loss: 1.2413 Acc: 0.9245
# Validation Loss: 1.4759 Acc: 0.6967
#
# Epoch 151
# -------------------------------
# loss: 1.258006  [    0/  940]
# Train      Loss: 1.2415 Acc: 0.9255
# Validation Loss: 1.5096 Acc: 0.6803
#
# Epoch 152
# -------------------------------
# loss: 1.257100  [    0/  940]
# Train      Loss: 1.2401 Acc: 0.9266
# Validation Loss: 1.5051 Acc: 0.6639
#
# Epoch 153
# -------------------------------
# loss: 1.272330  [    0/  940]
# Train      Loss: 1.2399 Acc: 0.9266
# Validation Loss: 1.4901 Acc: 0.6721
#
# Epoch 154
# -------------------------------
# loss: 1.226793  [    0/  940]
# Train      Loss: 1.2351 Acc: 0.9340
# Validation Loss: 1.4837 Acc: 0.6721
#
# Epoch 155
# -------------------------------
# loss: 1.227003  [    0/  940]
# Train      Loss: 1.2346 Acc: 0.9319
# Validation Loss: 1.4777 Acc: 0.6885
#
# Epoch 156
# -------------------------------
# loss: 1.227893  [    0/  940]
# Train      Loss: 1.2326 Acc: 0.9351
# Validation Loss: 1.4894 Acc: 0.6721
#
# Epoch 157
# -------------------------------
# loss: 1.228228  [    0/  940]
# Train      Loss: 1.2388 Acc: 0.9298
# Validation Loss: 1.4977 Acc: 0.6885
#
# Epoch 158
# -------------------------------
# loss: 1.268060  [    0/  940]
# Train      Loss: 1.2353 Acc: 0.9319
# Validation Loss: 1.4575 Acc: 0.7131
#
# Epoch 159
# -------------------------------
# loss: 1.226719  [    0/  940]
# Train      Loss: 1.2334 Acc: 0.9330
# Validation Loss: 1.5311 Acc: 0.6230
#
# Epoch 160
# -------------------------------
# loss: 1.229003  [    0/  940]
# Train      Loss: 1.2319 Acc: 0.9351
# Validation Loss: 1.5225 Acc: 0.6393
#
# Epoch 161
# -------------------------------
# loss: 1.229083  [    0/  940]
# Train      Loss: 1.2348 Acc: 0.9330
# Validation Loss: 1.5112 Acc: 0.6475
#
# Epoch 162
# -------------------------------
# loss: 1.255664  [    0/  940]
# Train      Loss: 1.2334 Acc: 0.9362
# Validation Loss: 1.4905 Acc: 0.6721
#
# Epoch 163
# -------------------------------
# loss: 1.226833  [    0/  940]
# Train      Loss: 1.2350 Acc: 0.9340
# Validation Loss: 1.4961 Acc: 0.6639
#
# Epoch 164
# -------------------------------
# loss: 1.228186  [    0/  940]
# Train      Loss: 1.2321 Acc: 0.9351
# Validation Loss: 1.4803 Acc: 0.6721
#
# Epoch 165
# -------------------------------
# loss: 1.226769  [    0/  940]
# Train      Loss: 1.2244 Acc: 0.9436
# Validation Loss: 1.5054 Acc: 0.6557
#
# Epoch 166
# -------------------------------
# loss: 1.227480  [    0/  940]
# Train      Loss: 1.2221 Acc: 0.9436
# Validation Loss: 1.4608 Acc: 0.6967
#
# Epoch 167
# -------------------------------
# loss: 1.227306  [    0/  940]
# Train      Loss: 1.2214 Acc: 0.9436
# Validation Loss: 1.4532 Acc: 0.7131
#
# Epoch 168
# -------------------------------
# loss: 1.225372  [    0/  940]
# Train      Loss: 1.2212 Acc: 0.9436
# Validation Loss: 1.4560 Acc: 0.7131
#
# Epoch 169
# -------------------------------
# loss: 1.226398  [    0/  940]
# Train      Loss: 1.2223 Acc: 0.9426
# Validation Loss: 1.4528 Acc: 0.7049
#
# Epoch 170
# -------------------------------
# loss: 1.226204  [    0/  940]
# Train      Loss: 1.2231 Acc: 0.9426
# Validation Loss: 1.4664 Acc: 0.6967
#
# Epoch 171
# -------------------------------
# loss: 1.227150  [    0/  940]
# Train      Loss: 1.2203 Acc: 0.9447
# Validation Loss: 1.4663 Acc: 0.7049
#
# Epoch 172
# -------------------------------
# loss: 1.226846  [    0/  940]
# Train      Loss: 1.2201 Acc: 0.9447
# Validation Loss: 1.4582 Acc: 0.7213
#
# Epoch 173
# -------------------------------
# loss: 1.226753  [    0/  940]
# Train      Loss: 1.2196 Acc: 0.9447
# Validation Loss: 1.4937 Acc: 0.6721
#
# Epoch 174
# -------------------------------
# loss: 1.228343  [    0/  940]
# Train      Loss: 1.2185 Acc: 0.9468
# Validation Loss: 1.4726 Acc: 0.6885
#
# Epoch 175
# -------------------------------
# loss: 1.229670  [    0/  940]
# Train      Loss: 1.2175 Acc: 0.9479
# Validation Loss: 1.4705 Acc: 0.6967
#
# Epoch 176
# -------------------------------
# loss: 1.226049  [    0/  940]
# Train      Loss: 1.2171 Acc: 0.9479
# Validation Loss: 1.4778 Acc: 0.6967
#
# Epoch 177
# -------------------------------
# loss: 1.226023  [    0/  940]
# Train      Loss: 1.2165 Acc: 0.9479
# Validation Loss: 1.4668 Acc: 0.7131
#
# Epoch 178
# -------------------------------
# loss: 1.226204  [    0/  940]
# Train      Loss: 1.2160 Acc: 0.9489
# Validation Loss: 1.4647 Acc: 0.7049
#
# Epoch 179
# -------------------------------
# loss: 1.226374  [    0/  940]
# Train      Loss: 1.2149 Acc: 0.9500
# Validation Loss: 1.4610 Acc: 0.6967
#
# Epoch 180
# -------------------------------
# loss: 1.226829  [    0/  940]
# Train      Loss: 1.2147 Acc: 0.9500
# Validation Loss: 1.4542 Acc: 0.7213
#
# Epoch 181
# -------------------------------
# loss: 1.226035  [    0/  940]
# Train      Loss: 1.2146 Acc: 0.9500
# Validation Loss: 1.4668 Acc: 0.6967
#
# Epoch 182
# -------------------------------
# loss: 1.225974  [    0/  940]
# Train      Loss: 1.2146 Acc: 0.9500
# Validation Loss: 1.4653 Acc: 0.7049
#
# Epoch 183
# -------------------------------
# loss: 1.225930  [    0/  940]
# Train      Loss: 1.2146 Acc: 0.9500
# Validation Loss: 1.4631 Acc: 0.6967
#
# Epoch 184
# -------------------------------
# loss: 1.225937  [    0/  940]
# Train      Loss: 1.2146 Acc: 0.9500
# Validation Loss: 1.4584 Acc: 0.7049
#
# Epoch 185
# -------------------------------
# loss: 1.225938  [    0/  940]
# Train      Loss: 1.2145 Acc: 0.9500
# Validation Loss: 1.4721 Acc: 0.6967
#
# Epoch 186
# -------------------------------
# loss: 1.226139  [    0/  940]
# Train      Loss: 1.2148 Acc: 0.9500
# Validation Loss: 1.4695 Acc: 0.7049
#
# Epoch 187
# -------------------------------
# loss: 1.226002  [    0/  940]
# Train      Loss: 1.2146 Acc: 0.9500
# Validation Loss: 1.4624 Acc: 0.7049
#
# Epoch 188
# -------------------------------
# loss: 1.225986  [    0/  940]
# Train      Loss: 1.2144 Acc: 0.9500
# Validation Loss: 1.4594 Acc: 0.7049
#
# Epoch 189
# -------------------------------
# loss: 1.225970  [    0/  940]
# Train      Loss: 1.2147 Acc: 0.9500
# Validation Loss: 1.4653 Acc: 0.7049
#
# Epoch 190
# -------------------------------
# loss: 1.226122  [    0/  940]
# Train      Loss: 1.2147 Acc: 0.9500
# Validation Loss: 1.4702 Acc: 0.6885
#
# Epoch 191
# -------------------------------
# loss: 1.226803  [    0/  940]
# Train      Loss: 1.2143 Acc: 0.9511
# Validation Loss: 1.4640 Acc: 0.6967
#
# Epoch 192
# -------------------------------
# loss: 1.226070  [    0/  940]
# Train      Loss: 1.2162 Acc: 0.9500
# Validation Loss: 1.4954 Acc: 0.6557
#
# Epoch 193
# -------------------------------
# loss: 1.226658  [    0/  940]
# Train      Loss: 1.2239 Acc: 0.9415
# Validation Loss: 1.5013 Acc: 0.6721
#
# Epoch 194
# -------------------------------
# loss: 1.227761  [    0/  940]
# Train      Loss: 1.2390 Acc: 0.9255
# Validation Loss: 1.4938 Acc: 0.6721
#
# Epoch 195
# -------------------------------
# loss: 1.265829  [    0/  940]
# Train      Loss: 1.2390 Acc: 0.9266
# Validation Loss: 1.5237 Acc: 0.6311
#
# Epoch 196
# -------------------------------
# loss: 1.248361  [    0/  940]
# Train      Loss: 1.2225 Acc: 0.9426
# Validation Loss: 1.4892 Acc: 0.6639
#
# Epoch 197
# -------------------------------
# loss: 1.228101  [    0/  940]
# Train      Loss: 1.2192 Acc: 0.9457
# Validation Loss: 1.4712 Acc: 0.6803
#
# Epoch 198
# -------------------------------
# loss: 1.227388  [    0/  940]
# Train      Loss: 1.2179 Acc: 0.9489
# Validation Loss: 1.4411 Acc: 0.7295
#
# Epoch 199
# -------------------------------
# loss: 1.226543  [    0/  940]
# Train      Loss: 1.2134 Acc: 0.9521
# Validation Loss: 1.4583 Acc: 0.6967
#
# Epoch 200
# -------------------------------
# loss: 1.227861  [    0/  940]
# Train      Loss: 1.2153 Acc: 0.9500
# Validation Loss: 1.4726 Acc: 0.6885
#
# Epoch 201
# -------------------------------
# loss: 1.226982  [    0/  940]
# Train      Loss: 1.2143 Acc: 0.9511
# Validation Loss: 1.4728 Acc: 0.6721
#
# Epoch 202
# -------------------------------
# loss: 1.227998  [    0/  940]
# Train      Loss: 1.2133 Acc: 0.9521
# Validation Loss: 1.4449 Acc: 0.7213
#
# Epoch 203
# -------------------------------
# loss: 1.228239  [    0/  940]
# Train      Loss: 1.2120 Acc: 0.9532
# Validation Loss: 1.4562 Acc: 0.7295
#
# Epoch 204
# -------------------------------
# loss: 1.227049  [    0/  940]
# Train      Loss: 1.2117 Acc: 0.9532
# Validation Loss: 1.4522 Acc: 0.7131
#
# Epoch 205
# -------------------------------
# loss: 1.226079  [    0/  940]
# Train      Loss: 1.2115 Acc: 0.9532
# Validation Loss: 1.4578 Acc: 0.6967
#
# Epoch 206
# -------------------------------
# loss: 1.226170  [    0/  940]
# Train      Loss: 1.2116 Acc: 0.9532
# Validation Loss: 1.4572 Acc: 0.7213
#
# Epoch 207
# -------------------------------
# loss: 1.226524  [    0/  940]
# Train      Loss: 1.2114 Acc: 0.9532
# Validation Loss: 1.4706 Acc: 0.6803
#
# Epoch 208
# -------------------------------
# loss: 1.226430  [    0/  940]
# Train      Loss: 1.2116 Acc: 0.9532
# Validation Loss: 1.4535 Acc: 0.7049
#
# Epoch 209
# -------------------------------
# loss: 1.226451  [    0/  940]
# Train      Loss: 1.2116 Acc: 0.9532
# Validation Loss: 1.4529 Acc: 0.7213
#
# Epoch 210
# -------------------------------
# loss: 1.226034  [    0/  940]
# Train      Loss: 1.2113 Acc: 0.9532
# Validation Loss: 1.4596 Acc: 0.7131
#
# Epoch 211
# -------------------------------
# loss: 1.226133  [    0/  940]
# Train      Loss: 1.2111 Acc: 0.9532
# Validation Loss: 1.4535 Acc: 0.7213
#
# Epoch 212
# -------------------------------
# loss: 1.226207  [    0/  940]
# Train      Loss: 1.2113 Acc: 0.9532
# Validation Loss: 1.4536 Acc: 0.7131
#
# Epoch 213
# -------------------------------
# loss: 1.226480  [    0/  940]
# Train      Loss: 1.2112 Acc: 0.9532
# Validation Loss: 1.4539 Acc: 0.7131
#
# Epoch 214
# -------------------------------
# loss: 1.226131  [    0/  940]
# Train      Loss: 1.2111 Acc: 0.9532
# Validation Loss: 1.4551 Acc: 0.7213
#
# Epoch 215
# -------------------------------
# loss: 1.226003  [    0/  940]
# Train      Loss: 1.2112 Acc: 0.9532
# Validation Loss: 1.4526 Acc: 0.7049
#
# Epoch 216
# -------------------------------
# loss: 1.226103  [    0/  940]
# Train      Loss: 1.2112 Acc: 0.9532
# Validation Loss: 1.4502 Acc: 0.7131
#
# Epoch 217
# -------------------------------
# loss: 1.226042  [    0/  940]
# Train      Loss: 1.2111 Acc: 0.9532
# Validation Loss: 1.4537 Acc: 0.7131
#
# Epoch 218
# -------------------------------
# loss: 1.226694  [    0/  940]
# Train      Loss: 1.2138 Acc: 0.9511
# Validation Loss: 1.4697 Acc: 0.6803
#
# Epoch 219
# -------------------------------
# loss: 1.227229  [    0/  940]
# Train      Loss: 1.2119 Acc: 0.9532
# Validation Loss: 1.4781 Acc: 0.6803
#
# Epoch 220
# -------------------------------
# loss: 1.229660  [    0/  940]
# Train      Loss: 1.2128 Acc: 0.9521
# Validation Loss: 1.4574 Acc: 0.7049
#
# Epoch 221
# -------------------------------
# loss: 1.227531  [    0/  940]
# Train      Loss: 1.2116 Acc: 0.9532
# Validation Loss: 1.4695 Acc: 0.6721
#
# Epoch 222
# -------------------------------
# loss: 1.227840  [    0/  940]
# Train      Loss: 1.2109 Acc: 0.9543
# Validation Loss: 1.4482 Acc: 0.7049
#
# Epoch 223
# -------------------------------
# loss: 1.226339  [    0/  940]
# Train      Loss: 1.2104 Acc: 0.9543
# Validation Loss: 1.4476 Acc: 0.7131
#
# Epoch 224
# -------------------------------
# loss: 1.226349  [    0/  940]
# Train      Loss: 1.2103 Acc: 0.9543
# Validation Loss: 1.4443 Acc: 0.7213
#
# Epoch 225
# -------------------------------
# loss: 1.226768  [    0/  940]
# Train      Loss: 1.2104 Acc: 0.9543
# Validation Loss: 1.4493 Acc: 0.7213
#
# Epoch 226
# -------------------------------
# loss: 1.226206  [    0/  940]
# Train      Loss: 1.2103 Acc: 0.9543
# Validation Loss: 1.4582 Acc: 0.7131
#
# Epoch 227
# -------------------------------
# loss: 1.226387  [    0/  940]
# Train      Loss: 1.2109 Acc: 0.9543
# Validation Loss: 1.4845 Acc: 0.6885
#
# Epoch 228
# -------------------------------
# loss: 1.226722  [    0/  940]
# Train      Loss: 1.2125 Acc: 0.9543
# Validation Loss: 1.4380 Acc: 0.7377
#
# Epoch 229
# -------------------------------
# loss: 1.226953  [    0/  940]
# Train      Loss: 1.2122 Acc: 0.9553
# Validation Loss: 1.5075 Acc: 0.6557
#
# Epoch 230
# -------------------------------
# loss: 1.240812  [    0/  940]
# Train      Loss: 1.2137 Acc: 0.9521
# Validation Loss: 1.4767 Acc: 0.6885
#
# Epoch 231
# -------------------------------
# loss: 1.228883  [    0/  940]
# Train      Loss: 1.2113 Acc: 0.9553
# Validation Loss: 1.4925 Acc: 0.6721
#
# Epoch 232
# -------------------------------
# loss: 1.242248  [    0/  940]
# Train      Loss: 1.2111 Acc: 0.9553
# Validation Loss: 1.4610 Acc: 0.7049
#
# Epoch 233
# -------------------------------
# loss: 1.228839  [    0/  940]
# Train      Loss: 1.2136 Acc: 0.9521
# Validation Loss: 1.4726 Acc: 0.6885
#
# Epoch 234
# -------------------------------
# loss: 1.232144  [    0/  940]
# Train      Loss: 1.2103 Acc: 0.9553
# Validation Loss: 1.4660 Acc: 0.6967
#
# Epoch 235
# -------------------------------
# loss: 1.226488  [    0/  940]
# Train      Loss: 1.2090 Acc: 0.9564
# Validation Loss: 1.4666 Acc: 0.6967
#
# Epoch 236
# -------------------------------
# loss: 1.227946  [    0/  940]
# Train      Loss: 1.2090 Acc: 0.9564
# Validation Loss: 1.4592 Acc: 0.6967
#
# Epoch 237
# -------------------------------
# loss: 1.227182  [    0/  940]
# Train      Loss: 1.2083 Acc: 0.9564
# Validation Loss: 1.4674 Acc: 0.6967
#
# Epoch 238
# -------------------------------
# loss: 1.226810  [    0/  940]
# Train      Loss: 1.2083 Acc: 0.9564
# Validation Loss: 1.4484 Acc: 0.7131
#
# Epoch 239
# -------------------------------
# loss: 1.227430  [    0/  940]
# Train      Loss: 1.2083 Acc: 0.9564
# Validation Loss: 1.4535 Acc: 0.7049
#
# Epoch 240
# -------------------------------
# loss: 1.226841  [    0/  940]
# Train      Loss: 1.2083 Acc: 0.9564
# Validation Loss: 1.4533 Acc: 0.7213
#
# Epoch 241
# -------------------------------
# loss: 1.227498  [    0/  940]
# Train      Loss: 1.2084 Acc: 0.9564
# Validation Loss: 1.4546 Acc: 0.7213
#
# Epoch 242
# -------------------------------
# loss: 1.226513  [    0/  940]
# Train      Loss: 1.2084 Acc: 0.9564
# Validation Loss: 1.4532 Acc: 0.7131
#
# Epoch 243
# -------------------------------
# loss: 1.227453  [    0/  940]
# Train      Loss: 1.2086 Acc: 0.9564
# Validation Loss: 1.4650 Acc: 0.6803
#
# Epoch 244
# -------------------------------
# loss: 1.227168  [    0/  940]
# Train      Loss: 1.2086 Acc: 0.9564
# Validation Loss: 1.4509 Acc: 0.7213
#
# Epoch 245
# -------------------------------
# loss: 1.227903  [    0/  940]
# Train      Loss: 1.2086 Acc: 0.9564
# Validation Loss: 1.4658 Acc: 0.7049
#
# Epoch 246
# -------------------------------
# loss: 1.226280  [    0/  940]
# Train      Loss: 1.2085 Acc: 0.9564
# Validation Loss: 1.4616 Acc: 0.7049
#
# Epoch 247
# -------------------------------
# loss: 1.226478  [    0/  940]
# Train      Loss: 1.2084 Acc: 0.9564
# Validation Loss: 1.4638 Acc: 0.6967
#
# Epoch 248
# -------------------------------
# loss: 1.227180  [    0/  940]
# Train      Loss: 1.2083 Acc: 0.9564
# Validation Loss: 1.4564 Acc: 0.7049
#
# Epoch 249
# -------------------------------
# loss: 1.226372  [    0/  940]
# Train      Loss: 1.2085 Acc: 0.9564
# Validation Loss: 1.4672 Acc: 0.6967
#
# Epoch 250
# -------------------------------
# loss: 1.226518  [    0/  940]
# Train      Loss: 1.2084 Acc: 0.9564
# Validation Loss: 1.4734 Acc: 0.6803
# Done for all 250 epochs in 21 minutes
#
# Best Validation accuracy: 0.7377049180327869

# %% [markdown]
# # Draw Graphs - Training and Validation

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=[6.4, 4.8],facecolor='white', edgecolor='black',dpi=100)

plt.title('Loss Curve')
plt.plot(train_loss,label='Training Loss')
plt.plot(val_loss,label='Validation Loss')
#plt.plot(test_loss,label='Testing Loss')  #comment this for inference
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

# %%
plt.figure(figsize=[6.4, 4.8],facecolor='white', edgecolor='black',dpi=100)
plt.title('Accuracy Curve')
plt.plot(train_acc,label='Training Accuracy')
plt.plot(val_acc,label='Validation Accuracy')
#plt.plot(test_acc,label='Testing Accuracy')  #comment this for inference
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

# %% [markdown]
# # Testing The Model

# %%
test_loop(test_dataloader, model, criterion)
# Out:
# Validation Loss: 1.5323 Acc: 0.6277
# (1.5322886088215713, tensor(0.6277, device='cuda:0', dtype=torch.float64))

# %%
torch.save(model, '/content/RavdessCNN.pth')

# %%
model2 = CNNNetwork().to(device)
model2.load_state_dict(best_model_wts)
# Out:
# <All keys matched successfully>

# %%
test_loop(test_dataloader, model2, criterion)
# Out:
# Validation Loss: 1.5323 Acc: 0.6277
# (1.5322886088215713, tensor(0.6277, device='cuda:0', dtype=torch.float64))

# %%
test_loop(val_dataloader, model2, criterion)
# Out:
# Validation Loss: 1.4380 Acc: 0.7377
# (1.438020715948011, tensor(0.7377, device='cuda:0', dtype=torch.float64))
